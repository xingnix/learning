% %% [markdown]
% Octave图像去噪
% 1. 生成图像
% 1. 添加噪声
% 1. 中值滤波

% %%
pkg load image
img=uint8(zeros(10,10));
img(3:7,3:7)=255;
imshow(img)

% %%
imgn=imnoise(img,'salt & pepper',0.1);
imshow(imgn)

% %%
imgm=medfilt2(imgn);
imshow(imgm)
