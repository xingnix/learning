# %% [markdown]
# # Pattern Recognition

# %% [markdown]
# # Pattern
#  pattern: A pattern is a regularity in the world, in human-made design, or in abstract ideas.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Definition
#
# - Pattern recognition is the automated recognition of patterns and regularities in data
# - The field of pattern recognition is concerned with the automatic discovery of regularities in data through the use of computer algorithms and with the use of these regularities to take actions such as classifying the data into different categories.

# %% [markdown]
# # Applications
#
# - statistical data analysis
# - signal processing
# - image analysis
# - information retrieval
# - bioinformatics
# - data compression
# - computer vision
# - image processing
# - machine learning

# %% [markdown]
# # Statistical data analysis
# ![image.png](attachment:image.png)

# %% [markdown]
# # Finger print feature
# ![image.png](attachment:image.png)

# %% [markdown]
# # Voice feature
# ![image.png](attachment:image.png)

# %% [markdown]
# # Handwriting recognition
# ![image.png](attachment:image.png)

# %% [markdown]
# # Image recognition example
# ![image.png](attachment:image.png)

# %% [markdown]
# # Image segmentation
# ![image.png](attachment:image.png)

# %% [markdown]
# # Detecting moving objects
# ![image.png](attachment:image.png)

# %% [markdown]
# # Infrared temperature measurement
# ![image.png](attachment:image.png)

# %% [markdown]
# # Face detection
# <video src='./VID_20160828_091943.webm' controls='controls'>

# %% [markdown]
# # Categories
# - supervised, where previously known patterns can be found in a given data
# - unsupervised, where entirely new patterns are discovered.

# %% [markdown]
# # Supervised
# ![image.png](attachment:image.png)

# %% [markdown]
# # Unsupervised
# ![image.png](attachment:image.png)

# %% [markdown]
# # Software
#
# - opencv
# - scikit-learn
# - scikit-image
# - tensorflow
# - pytorch

# %% [markdown]
# # Opencv example
# <video src="./opencv_pointclassifier_demo_VID_20161018_222915.webm"  controls='controls'>

# %% [markdown]
# # Related resource
# - Conference on Computer Vision and Pattern Recognition (CVPR)
# - Pattern Recognition (Journal of the Pattern Recognition Society)
# - Pattern Recognition Letters (PRL)
# - IEEE Transactions on Pattern Analysis and Machine Intelligence (TPAMI)
